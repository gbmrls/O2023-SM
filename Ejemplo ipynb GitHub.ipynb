# %% [markdown]
# # Título

# %% [markdown]
# ## Subtítulo

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.linspace(0, 5, 1000)
y = np.cos(21*x)

plt.figure()
plt.plot(x, y)

# %% [markdown]
# ## Subtítulo

# %% [markdown]
# Texto
